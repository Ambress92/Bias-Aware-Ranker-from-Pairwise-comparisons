# %%
import numpy as np
import choix
import opt_fair
from scipy.optimize import minimize
import scipy.stats as stats
import matplotlib.pyplot as plt
import random
from matplotlib import colors
import seaborn as sns

# %%
size = 100 #number of items
min_size = 30 
maj_size = size - min_size
num_reviewers = 50 #number of reviewers
pair_per_reviewer = 300 #number of pairs evaluated per reviewer

# %%
#init original scores
np.random.seed(42)
maxv=   5
minv=  -5

original = np.random.uniform(minv,maxv ,size = size)
#original[0:(maj_size)] = original[0:(maj_size)] - np.mean(original[0:(maj_size)])
#original[(maj_size):size] = original[(maj_size):size] - np.mean(original[(maj_size):size])
#init classes
classes = [0] * maj_size + [1] * min_size

# %%
def _full_alternate_optim(size, num_reviewers, pc_with_revs, original, revs_bias,  iters = 101, tol = 1e-5, gtol = 1e-5):
    '''x0 is the estimated scores
       y0 is the estimated bias for each reviewer'''
    x0 = np.zeros(size) #initial values
    y0 = np.zeros(num_reviewers) #initial values
    obj = []
    k_tau = []
    revs_mse = []
    

    for i in range(iters):

        # minimize with x fixed and update y
        res_y = minimize(lambda y: pc_with_revs.objective(x0, y), y0,tol = tol, jac=lambda y: pc_with_revs.gradient_revs(x0, y), options={"gtol": gtol,'maxiter': 1})
        y0 = res_y.x

        # minimize with y fixed and update x
        res_x = minimize(lambda x: pc_with_revs.objective(x, y0), x0,tol = tol, jac=lambda x: pc_with_revs.gradient_scores(x, y0), options={"gtol": gtol,'maxiter': 1})
        x0 = res_x.x

        obj_tmp = pc_with_revs.objective(x0, y0)
        k_tau_tmp,tmp = stats.kendalltau(x0,original)
        revs_mse_tmp = np.square(np.subtract(y0, [-x for x in revs_bias])).mean()
        
        obj.appendend(obj_tmp)
        k_tau.append(k_tau_tmp)
        revs_mse.append(revs_mse_tmp)
        
        if ((i) % 20 == 0):
            print(f"Iteration {i}: kendall_tau = {k_tau_tmp}, reviewers bias estimation = {revs_mse_tmp}")
            print(res_x.success)
            print(res_y.success)
            print(obj_tmp)

        if res_x.success and res_y.success:
            print("Minimum found!")
            print(f"Iteration {i}: x = {x0}, y = {y0}")
            #print(res_x.success)
            #print(res_y.success)
            break
    return x0,y0,k_tau,revs_mse

# %%
# %%time
np.random.seed(43)


revs_bias = np.random.uniform(-5, 5, size=num_reviewers)

biased_scores = opt_fair._create_matrix_biased_scores(original,revs_bias,classes)
revs_set =  opt_fair._create_pc_set_for_reviewers(biased_scores,pair_per_reviewer)

pc_with_revs = opt_fair.Pairwise_with_rev(data = revs_set, penalty = 0, classes = classes)
annot_bt,annot_bias,k_tau,revs_mse =  _full_alternate_optim(size, num_reviewers, pc_with_revs,  original, revs_bias, iters = 1000)
# Out:
# Iteration 0: kendall_tau = 0.9159595959595961, reviewers bias estimation = 8.729263434817334
# False
# False
# Iteration 20: kendall_tau = 0.9571717171717172, reviewers bias estimation = 0.6993151400560232
# False
# False
# Iteration 40: kendall_tau = 0.9636363636363638, reviewers bias estimation = 0.14894595656298462
# False
# False
# Iteration 60: kendall_tau = 0.9636363636363638, reviewers bias estimation = 0.15020827789801658
# False
# False
# Iteration 80: kendall_tau = 0.9636363636363638, reviewers bias estimation = 0.1502281819188419
# False
# False
# Minimum found!
# Iteration 85: x = [-0.79857159  4.6377658   2.69852523  1.13690379 -3.29874235 -3.07993099
#  -4.02111246  3.9330357   1.68969809  2.29543148 -4.4105821   5.10300663
#   3.57496975 -2.61776223 -2.89117319 -2.56435015 -1.69563547  0.66290285
#  -0.31715915 -2.10617387  1.23676346 -3.17389467 -1.67045336 -1.01612795
#   0.09334214  3.0861717  -2.5580061   0.34332792  1.50326697 -4.22100222
#   1.58364034 -3.01958514 -4.15282878  4.58259748  4.84781877  3.35110534
#  -1.97531137 -3.69396599  2.09546541 -0.18601976 -3.61768261  0.28768895
#  -4.32071024  4.15485605 -2.21242384  2.06429866 -1.76901295  0.76657203
#   0.6160576  -3.02356039  5.04034161  3.17367808  4.67777795  4.38739427
#   1.21594507  4.50908415 -3.68338644 -2.72862793 -4.25830814 -1.27980435
#  -0.6108891  -1.68267524  3.46053733 -1.00443319 -1.99820332  0.62519282
#  -3.65443611  3.3839883  -4.43592444  5.53069983  2.9331761  -2.68341173
#  -4.65159407  3.49272176  2.11187321  2.81535717  3.02998692 -4.08679415
#  -1.24233368 -3.58818773  4.02936697  1.59018778 -1.35782974 -4.33589027
#  -1.79586415 -1.47513558  3.03046914  1.84534379  4.00762367 -0.16274455
#  -3.21511572  2.2981677   2.78465812  0.79711983  3.13428875  0.14241347
#   0.4584494  -0.0258023  -4.91357692 -3.56830764], y = [ 3.31407082 -1.35768416  4.36269092  2.64147333  1.53076681 -3.53511611
#  -1.66223088 -0.33089545  5.12414381 -2.01887841  1.76312467 -2.93955076
#   1.95037409  3.87336875 -3.30955226  2.6287251   1.01925826  1.28197652
#   4.31447415 -4.11774787 -4.28705819 -4.12152214  0.67149254 -4.3583662
#   0.64428163 -2.31849802  4.03388119 -3.79056574  1.47673492  2.36337265
#   5.8409505  -0.24989264  0.05169419 -1.41410827 -4.90757156 -4.01124878
#  -4.21163023 -0.57569618  3.98301274  3.99543994 -4.83666907  0.67995435
#  -3.87437539 -1.29647265 -1.71879772  2.17695798 -4.0628316   3.12996416
#   1.09247313 -4.71556759]
# CPU times: total: 1min 22s
# Wall time: 56.8 s

# %%
k = k_tau[:]
plt.plot(range(len(k)), [1-q for q in k])
plt.xlabel('Iters')
plt.ylabel('Kendall Tau error')
plt.title('Convergence of ranking error')
plt.show()

# %%
mse = revs_mse[:]
plt.plot(range(len(mse)), mse)
plt.xlabel('Iters')
plt.ylabel('Annotators bias estimation error')
plt.title('Convergence of Annotators bias estimation')
plt.show()
